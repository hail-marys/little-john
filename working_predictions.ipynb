# %%
import pandas as pd
from datetime import datetime
import finnhub
import mplfinance as mpf

client = finnhub.Client(api_key='brqm9efrh5rce3ls8mdg')

def get_data(ticker):
    return client.stock_candles(ticker, 'D', 1593586800, 1596178800)

aapl_july = get_data('AAPL')
del aapl_july['s']

print(aapl_july)
# Out:
# {'c': [363.4547, 363.4547, 373.1772, 372.0193, 380.6836, 382.3207, 382.9895, 381.2227, 387.5313, 390.1965, 385.3951, 384.6165, 392.7219, 387.3017, 388.3897, 370.7116, 369.7932, 378.5574, 372.3387, 379.4758, 384.0675], 'h': [366.7047, 369.8147, 375.1071, 377.9492, 380.8136, 384.5807, 383.2295, 399.1327, 388.3213, 396.2865, 388.9251, 387.8965, 393.2919, 396.3017, 391.1997, 387.6416, 371.2133, 379.62, 377.5287, 380.2358, 384.4975], 'l': [363.2547, 362.9847, 369.1971, 371.5593, 375.6736, 378.0007, 378.1295, 380.3427, 374.8113, 385.2565, 382.9251, 382.6665, 383.5419, 386.2717, 385.7097, 367.3716, 355.9132, 373.2375, 372.3187, 374.1658, 374.3775], 'o': [364.4647, 367.1947, 369.3271, 374.7393, 376.0336, 384.3607, 380.6495, 388.3727, 378.6613, 395.2565, 385.5551, 387.2565, 384.9619, 395.9917, 386.0697, 387.3216, 363.2833, 374.84, 376.7987, 374.3158, 376.0575], 't': [1593561600, 1593648000, 1593993600, 1594080000, 1594166400, 1594252800, 1594339200, 1594598400, 1594684800, 1594771200, 1594857600, 1594944000, 1595203200, 1595289600, 1595376000, 1595462400, 1595548800, 1595808000, 1595894400, 1595980800, 1596067200], 'v': [27684300, 28510400, 29663900, 28106100, 29273000, 31410700, 22564300, 47912300, 42747300, 38299500, 27644400, 23046700, 22579500, 25911500, 22250400, 49251100, 46359700, 59134131, 25906400, 22582300, 39532500]}

# %%
df = pd.DataFrame.from_dict(aapl_july)
df
# Out:
#            c         h         l         o           t         v
# 0   363.4547  366.7047  363.2547  364.4647  1593561600  27684300
# 1   363.4547  369.8147  362.9847  367.1947  1593648000  28510400
# 2   373.1772  375.1071  369.1971  369.3271  1593993600  29663900
# 3   372.0193  377.9492  371.5593  374.7393  1594080000  28106100
# 4   380.6836  380.8136  375.6736  376.0336  1594166400  29273000
# 5   382.3207  384.5807  378.0007  384.3607  1594252800  31410700
# 6   382.9895  383.2295  378.1295  380.6495  1594339200  22564300
# 7   381.2227  399.1327  380.3427  388.3727  1594598400  47912300
# 8   387.5313  388.3213  374.8113  378.6613  1594684800  42747300
# 9   390.1965  396.2865  385.2565  395.2565  1594771200  38299500
# 10  385.3951  388.9251  382.9251  385.5551  1594857600  27644400
# 11  384.6165  387.8965  382.6665  387.2565  1594944000  23046700
# 12  392.7219  393.2919  383.5419  384.9619  1595203200  22579500
# 13  387.3017  396.3017  386.2717  395.9917  1595289600  25911500
# 14  388.3897  391.1997  385.7097  386.0697  1595376000  22250400
# 15  370.7116  387.6416  367.3716  387.3216  1595462400  49251100
# 16  369.7932  371.2133  355.9132  363.2833  1595548800  46359700
# 17  378.5574  379.6200  373.2375  374.8400  1595808000  59134131
# 18  372.3387  377.5287  372.3187  376.7987  1595894400  25906400
# 19  379.4758  380.2358  374.1658  374.3158  1595980800  22582300
# 20  384.0675  384.4975  374.3775  376.0575  1596067200  39532500

# 15  370.7116  387.6416  367.3716  387.3216 2020-07-22 17:00:00  49251100
# 16  369.7932  371.2133  355.9132  363.2833 2020-07-23 17:00:00  46359700
# 17  378.5574  379.6200  373.2375  374.8400 2020-07-26 17:00:00  59134131
# 18  372.3387  377.5287  372.3187  376.7987 2020-07-27 17:00:00  25906400
# 19  379.4758  380.2358  374.1658  374.3158 2020-07-28 17:00:00  22582300
# 20  384.0675  384.4975  374.3775  376.0575 2020-07-29 17:00:00  39532500

# %%
df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
df
# Out:
#         Open      High       Low     Close    Volume
# 0   364.4647  366.7047  363.2547  363.4547  27684300
# 1   367.1947  369.8147  362.9847  363.4547  28510400
# 2   369.3271  375.1071  369.1971  373.1772  29663900
# 3   374.7393  377.9492  371.5593  372.0193  28106100
# 4   376.0336  380.8136  375.6736  380.6836  29273000
# 5   384.3607  384.5807  378.0007  382.3207  31410700
# 6   380.6495  383.2295  378.1295  382.9895  22564300
# 7   388.3727  399.1327  380.3427  381.2227  47912300
# 8   378.6613  388.3213  374.8113  387.5313  42747300
# 9   395.2565  396.2865  385.2565  390.1965  38299500
# 10  385.5551  388.9251  382.9251  385.3951  27644400
# 11  387.2565  387.8965  382.6665  384.6165  23046700
# 12  384.9619  393.2919  383.5419  392.7219  22579500
# 13  395.9917  396.3017  386.2717  387.3017  25911500
# 14  386.0697  391.1997  385.7097  388.3897  22250400
# 15  387.3216  387.6416  367.3716  370.7116  49251100
# 16  363.2833  371.2133  355.9132  369.7932  46359700
# 17  374.8400  379.6200  373.2375  378.5574  59134131
# 18  376.7987  377.5287  372.3187  372.3387  25906400
# 19  374.3158  380.2358  374.1658  379.4758  22582300
# 20  376.0575  384.4975  374.3775  384.0675  39532500

# %%
def candlestick_plot(ticker, timeframe, start, end):
    data = client.stock_candles(ticker, timeframe, start, end)
    del data['s']
    df = pd.DataFrame.from_dict(data)
    df['t'] = df['t'].apply(lambda x: datetime.fromtimestamp(x))
    df = df.rename(columns={'c': 'Close', 'h': 'High', 'l': 'Low', 'o': 'Open', 't': 'Date', 'v': 'Volume'})
    df.set_index('Date', inplace=True)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
    mpf.plot(df, type='candle')

# %%
candlestick_plot('AAPL', 'D', 1584164208, 1597383408)

# %%
def get_candlestick_data(ticker, timeframe, start, end):
    data = client.stock_candles(ticker, timeframe, start, end)
    del data['s']
    df = pd.DataFrame.from_dict(data)
    df['t'] = df['t'].apply(lambda x: datetime.fromtimestamp(x))
    df = df.rename(columns={'c': 'Close', 'h': 'High', 'l': 'Low', 'o': 'Open', 't': 'Date', 'v': 'Volume'})
    df.set_index('Date', inplace=True)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
    return df

# %%
apple_data = get_candlestick_data('AAPL', 'D', 1281764208, 1597383408)
print(apple_data)
# Out:
#                          Open      High       Low     Close     Volume
# Date
# 2010-08-15 17:00:00   30.5622   30.9094   30.4251   30.5708   79607500
# 2010-08-16 17:00:00   30.8353   31.4853   30.7096   31.1053  105660100
# 2010-08-17 17:00:00   31.1397   31.4697   31.0282   31.2411   84924000
# 2010-08-18 17:00:00   31.2702   31.3616   30.6759   30.8473  106676500
# 2010-08-19 17:00:00   30.7820   31.4291   30.7262   30.8177   96057500
# ...                       ...       ...       ...       ...        ...
# 2020-08-06 17:00:00  452.8200  454.7000  441.1700  444.4500   49453300
# 2020-08-09 17:00:00  450.4000  455.1000  440.0000  450.9100   53100900
# 2020-08-10 17:00:00  447.8800  449.9300  436.4300  437.5000   46975600
# 2020-08-11 17:00:00  441.9900  453.1000  441.1900  452.0400   41486200
# 2020-08-12 17:00:00  457.7200  464.1700  455.7100  460.0400   52420000
#
# [2517 rows x 5 columns]

# %%
import numpy as np
import matplotlib.pyplot as plot
# remind team to install sklearn
from sklearn.preprocessing import MinMaxScaler

# %%
open_data = apple_data.iloc[:, 0:1].values
open_data = open_data.reshape(-1,1)

scaler = MinMaxScaler(feature_range = (0, 1))

open_data = scaler.fit_transform(open_data)
open_data
# Out:
# array([[0.00296572],
#        [0.00360317],
#        [0.00431367],
#        ...,
#        [0.97703233],
#        [0.96328441],
#        [1.        ]])

# %%
open_data.shape
data_train = open_data[:1001]
data_test = open_data[975:]

# %%
# Creating X_test and Y_test tensors
x_train = []
y_train = []
for i in range(50, 1001):
    x_train.append(data_train[i-50:i])
    y_train.append(data_train[i])

x_train = np.asarray(x_train)
y_train = np.asarray(y_train)

# %%
#Creating X_test and Y_Test tensors
x_test = []
y_test = []

for i in range(50,data_test.shape[0]):
  x_test.append(data_test[i-50:i])
  y_test.append(data_test[i])
x_test = np.asarray(x_test)
y_test = np.asarray(y_test)

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import activations
from tensorflow.keras.callbacks import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

model = Sequential([
  layers.LSTM(units=96, return_sequences=True, input_shape=(50,1)),
  layers.Dropout(0.2),
  layers.LSTM(units=96, return_sequences=True),
  layers.Dropout(0.2),
  layers.LSTM(units=96, return_sequences=True),
  layers.Dropout(0.2),
  layers.LSTM(units=96, return_sequences=True),
  layers.Dropout(0.2),
  layers.LSTM(units=96, return_sequences=True),
  layers.Dropout(0.2),
  layers.LSTM(units=96),
  layers.Dropout(0.2),
  layers.Dense(1)
])

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

mcp_save = ModelCheckpoint('mdl_wts.hdf5', save_best_only=True, monitor='val_loss', mode='min')
earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')

model.fit(x_train,y_train, epochs=100, batch_size=32, validation_split=0.15, callbacks=[mcp_save,earlyStopping])
# Out:
# Epoch 1/100
# 26/26 [==============================] - 4s 161ms/step - loss: 6.5613e-04 - val_loss: 4.8276e-04
# Epoch 2/100
# 26/26 [==============================] - 2s 59ms/step - loss: 2.0935e-04 - val_loss: 9.0882e-05
# Epoch 3/100
# 26/26 [==============================] - 2s 59ms/step - loss: 1.2391e-04 - val_loss: 6.4959e-05
# Epoch 4/100
# 26/26 [==============================] - 1s 57ms/step - loss: 1.0938e-04 - val_loss: 6.1836e-05
# Epoch 5/100
# 26/26 [==============================] - 1s 56ms/step - loss: 1.2393e-04 - val_loss: 3.3655e-04
# Epoch 6/100
# 26/26 [==============================] - 1s 57ms/step - loss: 1.2691e-04 - val_loss: 5.5474e-05
# Epoch 7/100
# 26/26 [==============================] - 1s 55ms/step - loss: 9.3481e-05 - val_loss: 2.1598e-04
# Epoch 8/100
# 26/26 [==============================] - 1s 55ms/step - loss: 1.1001e-04 - val_loss: 1.1004e-04
# Epoch 9/100
# 26/26 [==============================] - 2s 58ms/step - loss: 9.5458e-05 - val_loss: 5.2705e-05
# Epoch 10/100
# 26/26 [==============================] - 1s 55ms/step - loss: 9.1077e-05 - val_loss: 5.4468e-05
# Epoch 11/100
# 26/26 [==============================] - 1s 53ms/step - loss: 9.8563e-05 - val_loss: 8.9703e-05
# Epoch 12/100
100
# 26/26 [==============================] - 1s 56ms/step - loss: 3.3977e-05 - val_loss: 2.4563e-05
# Epoch 73/100
# 26/26 [==============================] - 1s 54ms/step - loss: 3.5039e-05 - val_loss: 2.0838e-05
# Epoch 74/100
# 26/26 [==============================] - 1s 56ms/step - loss: 3.5728e-05 - val_loss: 2.1158e-05
# Epoch 75/100
# 26/26 [==============================] - 1s 55ms/step - loss: 3.3267e-05 - val_loss: 3.5146e-05
# Epoch 76/100
# 26/26 [==============================] - 1s 57ms/step - loss: 3.6015e-05 - val_loss: 1.9065e-05
# Epoch 77/100
# 26/26 [==============================] - 1s 58ms/step - loss: 4.0452e-05 - val_loss: 9.6123e-05
# Epoch 78/100
# 26/26 [==============================] - 1s 57ms/step - loss: 4.6161e-05 - val_loss: 8.0708e-05
# Epoch 79/100
# 26/26 [==============================] - 1s 54ms/step - loss: 3.9484e-05 - val_loss: 2.3735e-05
# Epoch 80/100
# 26/26 [==============================] - 1s 53ms/step - loss: 3.6895e-05 - val_loss: 2.7951e-05
# Epoch 81/100
# 26/26 [==============================] - 1s 53ms/step - loss: 3.5620e-05 - val_loss: 3.4580e-05
# Epoch 82/100
# 26/26 [==============================] - 1s 57ms/step - loss: 3.5410e-05 - val_loss: 4.2243e-05
# Epoch 83/100
# 26/26 [==============================] - 2s 59ms/step - loss: 3.9796e-05 - val_loss: 1.8403e-05
# Epoch 84/100
# 26/26 [==============================] - 1s 54ms/step - loss: 3.0189e-05 - val_loss: 2.1689e-05
# Epoch 85/100
# 26/26 [==============================] - 1s 54ms/step - loss: 2.7708e-05 - val_loss: 4.1100e-05
# Epoch 86/100
# 26/26 [==============================] - 1s 56ms/step - loss: 3.1602e-05 - val_loss: 2.3188e-05
# Epoch 87/100
# 26/26 [==============================] - 2s 59ms/step - loss: 3.1613e-05 - val_loss: 1.7879e-05
# Epoch 88/100
# 26/26 [==============================] - 1s 58ms/step - loss: 2.8617e-05 - val_loss: 2.8071e-05
# Epoch 89/100
# 26/26 [==============================] - 1s 55ms/step - loss: 3.0082e-05 - val_loss: 1.8985e-05
# Epoch 90/100
# 26/26 [==============================] - 1s 55ms/step - loss: 3.4678e-05 - val_loss: 2.4271e-05
# Epoch 91/100
# 26/26 [==============================] - 1s 55ms/step - loss: 4.5566e-05 - val_loss: 1.8275e-05
# Epoch 92/100
# 26/26 [==============================] - 1s 55ms/step - loss: 2.9605e-05 - val_loss: 7.8171e-05
# Epoch 93/100
# 26/26 [==============================] - 1s 56ms/step - loss: 3.7407e-05 - val_loss: 1.9971e-05
# Epoch 94/100
# 26/26 [==============================] - 1s 57ms/step - loss: 2.9226e-05 - val_loss: 2.0312e-05
# Epoch 95/100
# 26/26 [==============================] - 2s 58ms/step - loss: 2.9752e-05 - val_loss: 1.5050e-05
# Epoch 96/100
# 26/26 [==============================] - 1s 55ms/step - loss: 2.7956e-05 - val_loss: 6.1497e-05
# Epoch 97/100
# 26/26 [==============================] - 1s 55ms/step - loss: 3.3907e-05 - val_loss: 5.2135e-05
# Epoch 98/100
# 26/26 [==============================] - 1s 57ms/step - loss: 3.0247e-05 - val_loss: 1.8372e-05
# Epoch 99/100
# 26/26 [==============================] - 1s 55ms/step - loss: 2.8415e-05 - val_loss: 1.5936e-05
# Epoch 100/100
# 26/26 [==============================] - 2s 58ms/step - loss: 2.8330e-05 - val_loss: 1.4063e-05

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
prediction_model = load_model('mdl_wts.hdf5')

predictions = prediction_model.predict(x_test)
predictions = scaler.inverse_transform(predictions)
open_data = scaler.inverse_transform(open_data)

fig, ax = plt.subplots(figsize=(8,4))
plt.plot(open_data, color="red", label="True Price of Stock")
ax.plot(range(len(y_train)+50,len(y_train)+50+len(predictions)),predictions, color='blue', label='Predicted Testing Price')
plt.legend()

# %%
print(predictions.shape)
# Out:
# (1492, 1)
